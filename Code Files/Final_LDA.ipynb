# %%
import pandas as pd
import csv
papers = pd.read_csv('Book1.csv',encoding='ISO-8859-1')

# %%
papers
# Out:
#      Serial_no  Group_id source doc_code         acquirer_name  \
# 0            1       1.0            AIU1                   8x8
# 1            2       2.0            AIE1             Accenture
# 2            3       2.0            AIE2             Accenture
# 3            4       2.0            AIE3             Accenture
# 4            5       2.0            AIE4             Accenture
# ..         ...       ...             ...                   ...
# 418        423       NaN             NaN               Telstra
# 419        424       NaN             NaN            MasterCard
# 420        425       NaN             NaN                 Apple
# 421        426       NaN             NaN             Microsoft
# 422        427       NaN             NaN  Luxoft Holding, Inc
#
#     acquirer_ISIN code acquirer_GV key acquirer_country  \
# 0         US2829141009           65021              USA
# 1         IE00B4BNMY34          143357          Ireland
# 2         IE00B4BNMY34          143357          Ireland
# 3         IE00B4BNMY34          143357          Ireland
# 4         IE00B4BNMY34          143357          Ireland
# ..                 ...             ...              ...
# 418       AU000000TLS2             NaN        Australia
# 419       US57636Q1040             NaN              USA
# 420       US0378331005            1690              USA
# 421       US5949181045           12141              USA
# 422       VGG572791041             NaN      Switzerland
#
#     ticker_symbol_acquirer   PERMNO date_of_press_report target_firm_name  \
# 0                     EGHT  85177.0            5/25/2018        MarianaIQ
# 1                      ACN  91814.0            1/12/2019      Knowledgent
# 2                      ACN  70308.0            11/7/2018  Intrigo Systems
# 3                      ACN  87299.0            7/22/2015     Chaotic Moon
# 4                      ACN  87299.0             7/3/2015       Brightstep
# ..                     ...      ...                  ...              ...
# 418                    TLS      NaN            3/26/2015        Dr Foster
# 419                     MA  91233.0            4/29/2015              APT
# 420                   AAPL  14593.0             1/8/2016         Emotient
# 421                   MSFT  10107.0             9/4/2015       VoloMetrix
# 422                   LXFT      NaN            7/19/2016      Insys group
#
#     target_firm_country                                            Heading  \
# 0                   USA  8x8 Acquires MarianaIQ to Strengthen AI Capabi...
# 1                   USA  Accenture Buys US Data Intelligence Firm Knowl...
# 2                   USA             Accenture acquires SAP partner Intrigo
# 3                   USA                                                NaN
# 4                Sweden                                                NaN
# ..                  ...                                                ...
# 418                  UK                                                NaN
# 419                  UK                                                NaN
# 420                 NaN                                                NaN
# 421                 USA                                                NaN
# 422                USA                                                 NaN
#
#                                                   Text
# 0    8x8, Inc.(NYSE:EGHT), a leading provider of cl...
# 1    Global management consultancy Accenture has ac...
# 2    Accenture has acquired Intrigo Systems, a U.S....
# 3    US-based management consulting, technology ser...
# 4    Accenture(NYSE:ACN) has acquired Brightstep, a...
# ..                                                 ...
# 418  MedioÃ¢â¬â¢s workforce of around 60 will sta...
# 419  APT founder Jim Manzi told Computing thatÃÂ p...
# 420  helped firms to get "about three per cent bett...
# 421  VoloMetrix organisational analytics software a...
# 422  Switzerland-based software development service...
#
# [423 rows x 14 columns]

# %%
stopwords1=[]
stopwords2=[]
print(len(papers))
for i in range(len(papers)):
    acquirer_name = str(papers['acquirer_name'][i].lower()).split()
    acquirer_name=' '.join(acquirer_name)
    stopwords1.append(acquirer_name)
for i in range(len(papers)):
    target_firm_name = str(papers['target_firm_name'][i].lower()).split()
    target_firm_name=' '.join(target_firm_name)
    stopwords2.append(target_firm_name)
print(stopwords2)

# Remove the columns
papers = papers.drop(columns=['Serial_no','Group_id','source doc_code','acquirer_name','acquirer_ISIN code','acquirer_GV key','acquirer_country','ticker_symbol_acquirer','PERMNO','date_of_press_report','target_firm_name','target_firm_country','Heading'], axis=1)
# sample only 10 papers - for demonstration purposes
#papers = papers.sample(25)
# Print out the first rows of papers
papers.head(5)
# Out:
# 423
# ['marianaiq', 'knowledgent', 'intrigo systems', 'chaotic moon', 'brightstep', 'changetrack research pty ltd', 'wireless co., ltd.', 'morphormics, inc.', 'adman media', 'abco gases', 'cyberfend', 'mediamath', 'onpoint medical diagnostics', 'harvard teaching hospital', 'rackspace hosting inc.,', 'ge', 'buysight, inc.', 'clara analytics', 'dynasty marketplace, inc.', 'perceptio', 'gliimpse', 'siri', 'affectiva', '3m', 'illuminate labs', 'grip entertainment technology assets', 'indix', 'mashreq bank', 'ovio technologies inc.', 'hive', 'c3.ai', 'high-tech bridge sa', 'benefit informatics, inc', 'heavywater', 'cylance', 'sparkcognition', 'sparkcognition', 'arxspan llc', 'arcsoft', 'tsmc', 'atomwise inc.', 'mindmeld', 'prime research', 'feedzai', 'hortonworks inc.', 'sualab', 'execuserve corp', 'inuvo', 'merkle inc.', 'intific inc.', 'medidata solutions, inc.', 'cyclane', 'optina diagnostics', 'decide.com', 'hunch.com', 'morgan stanley', 'sinequa', 'igodigital', 'wit.ai', 'iris.tv', 'essential discovery, inc.', 'orexo', 'bitspeed', 'intel', 'nvidia', 'tampa general hospital', 'nanle electric wheelchair co.', 'walmart', 'rage frameworks', 'dxc technology', 'flywheel', 'looker', 'iridescent', 'boston dymanics', 'jetpac', 'mobvoi', 'like.com', 'clever sense', 'netobjex, inc', 'shift technology', 'upmc', 'desti', 'c3', 'mapr', 'amira learning', 'ayasdi inc', 'timex group', 'pelco(tm) by schneider electric', 'softlayer', 'twitter', 'bloomfire', 'nvidia', 'i2 holdings ltd', 'varicent software', 'alchemyapi', 'merge healthcare', 'weather company', 'novo nordisk', 'identascan corporation', 'spher inc.', 'the irus group, inc', 'university of illinois urbana-champaign', 'c3 iot', 'indisys', 'nervana systems', 'lenovo', 'outsideiq', 'evolution robotics, inc.', 'cruising store', 'zeller corporation', 'mount sinai', 'landing ai', 'amadesa ltd', 'drone racing league', 'pointr data inc', 'hayes', 'united therapeutics', 'viz.ai', 'adastra corporation', 'cerebri ai', 'lg', 'lobe', 'zestfinance', 'generali group', 'versium', 'genee', 'message.io', 'humana inc.', 'silvercloud health', 'datarobot', 'eiã\x82â³', 'byallaccounts', 'xerox research center', 'allegro.ai', 'ar ecommerce', 'causata', 'ipsoft', 'avitas systems', 'nuance communications inc.', 'mellanox', 'toyota', 'arm technology', 'zenrin', 'sas', 'trace3', 'publicis', 'almotive', 'vertical health solutions, inc.', 'akasha center for integrative medicine, llc', 'rightnow', 'kologik, llc.', 'mobiry', 'polaris alpha', 'freshworks', 'boys & girls clubs of western pennsylvania', 'coldlight', 'vtec laboratories', 'evolution ai corp', 'hanvon technology', 'destination marketing association international', 'x plus two solutions inc', 'transunion', 'kensho technologies inc.', 'orkus', 'overwatchid', 'google', 'twin prime', 'kxen', 'espressive', 'intellibot robotics', 'grapevine', 'pixable', 'avnera corp.', 'predikly', 'optimaize, inc.', 'taboola', 'thread genius', 'immunet', 'monitr', 'iheartmedia', 'lightminer systems', 'deep instinct', 'collabrx, inc.', 'crane wireless monitoring solutions', 'cape analytics', 'akerman', 'layer 6', "definiens' earth sciences", 'nexpense', 'fabula ai', 'madbits', 'whetlab', 'comet.ml', 'techlaw solutions', 'appetizer mobile', 'cronto', 'golden boy promotions', 'dalet', 'machine box inc.', 'art19', 'wazee digital', 'pri management group', 'ukplc', 'oneriot', 'ai.io', 'identified', 'summly', 'lookflow', 'wander', 'bluesence innovation group s.l.', 'crowdstrike holdings', 'moodstocks', 'datahug limited', 'expertmaker', 'swiftkey', 'magic pony', 'medtech sa', 'vidi systems', 'sybenetix ltd.', 'scyfer b.v.', 'day software', 'green hat', 'magirus', 'mensaelect s.a.', 'lemagit', 'deepmind', 'vocaliq', 'perceptio', 'exini', 'spektral', 'softvision', 'smadex', 'zonefox', 'talkwalker', 'logicalware ltd.', 'test motors', 'technicolor', 'snips sas', 'grazper technologies', 'presenso ltd', 'designit', 'h.c. starck ceramics', 'kmd', 'mudano', 'miner & kasch', 'labanswer', 'search tec ...
#                                                 Text
# 0  8x8, Inc.(NYSE:EGHT), a leading provider of cl...
# 1  Global management consultancy Accenture has ac...
# 2  Accenture has acquired Intrigo Systems, a U.S....
# 3  US-based management consulting, technology ser...
# 4  Accenture(NYSE:ACN) has acquired Brightstep, a...

# %%
# Load the regular expression library
import re
# Remove punctuation
papers['paper_text_processed'] = papers['Text'].map(lambda x: re.sub('[,\.!?]',' ', str(x)))
# Convert the titles to lowercase
papers['paper_text_processed'] = papers['Text'].map(lambda x: str(x).lower())
# Print out the first rows of papers
papers['paper_text_processed'].head()
# Out:
# 0    8x8, inc.(nyse:eght), a leading provider of cl...
# 1    global management consultancy accenture has ac...
# 2    accenture has acquired intrigo systems, a u.s....
# 3    us-based management consulting, technology ser...
# 4    accenture(nyse:acn) has acquired brightstep, a...
# Name: paper_text_processed, dtype: object

# %%
# %%time
import gensim
from gensim.utils import simple_preprocess
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data = papers.paper_text_processed.values.tolist()
print(data)
data_words = list(sent_to_words(data))
original_data = data_words
print(data_words[:2])
# Out:
# ['8x8, inc.(nyse:eght), a leading provider of cloud phone, meeting, collaboration and contact center solutions,announced the acquisition of marianaiq (miq), a high-growth silicon valley startup, as part of the strategic investments it has been making in ai and machine learning. miq brings deep learning capabilities to the newly announced x series to transform both employee and customer experience. the miq team, including founders soumyadeb mitra and venkat nagaswamy, have been leaders in applying ai and deep learning to practical business problems since 2013, and join 8x8 to strengthen ai capabilities for enterprise communications."8x8 has continuously evolved itself to provide best-in-class enterprise communications to our customers.with the acquisition of marianaiq, we are fundamentally transforming how customers and employees interact through one system of engagement, and how companies optimize valuable moments of customer engagement with one set of data in one system of intelligence," said dejan deklich, chief product officer,8x8. "we are thrilled to add top notch ai talent to strengthen 8x8\'s market leadership in the $40 billion-dollar enterprise engagement management market."customer experience is the cios\' new battlefield. according to gartner\'s 2018 cio agenda survey, nearly half of cios plan to deploy artificial intelligence to improve customer experience. the 8x8 ai and machine learning team will help cios win the customer experience battle with these key capabilities: context-rich customer engagements: the 8x8 ai team will enhance the x series single system of intelligence platform to weave in contextual personalization for omni-channel services. by infusing miq\'s deep learning capabilities into 8x8\'s x series, contact center agents can have detailed information on previous interactions, complete customer history, and a 360-degree context before they even start a conversation. intelligent call routing: 8x8\'s ai capabilities will bring intelligent call routing to call centers. as a critical component of the customer experience transformation, intelligent routing will identify the caller and the reason for the call to assign the customer to the right agent, executive or subject matter expert. this significantly speeds first-call resolution and transforms the overall customer experience. speech analytics: voice of the customer insights enable companies to optimize customer experiences through data-driven decisions. with powerful speech analytics enabled by 8x8, companies can now analyze customer interactions for compliance, deeper insights, and agent performance purposes. 8x8\'s speech analytics powered by natural language processing technology can help agents, inside sales, and customer success teams effectively identify upsell opportunities or escalate at-risk customers to the highest-level of service."acquisitions remain a key part of our strategy to continuously innovate and disrupt the enterprise communications space," said bryan martin, cto, 8x8. "we acquired sameroom last year to enhance our team collaboration capabilities, and we are one of the very few players offering an interoperable chat system that can speak to slack, stride, and other enterprise-level chat applications. the acquisition of marianaiq is the right investment in making x series, a single system of engagement and intelligence to deliver exceptional experience for both employees and customers."', 'global management consultancy accenture has acquired us data intelligence company knowledgent for an undisclosed sum. knowledgent uses machine learning and ai technologies to support clients through `digital transformation`programs. the firm`s artificial intelligence lab is a hub for research, innovation, and collaboration on digital disruption technologies such as ai, machine learning, and internet of things (iot). based in new jersey, it employs more than 300 `informationists` who provide data strategy, architecture, engineering and management ...
# [['inc', 'nyse', 'eght', 'leading', 'provider', 'of', 'cloud', 'phone', 'meeting', 'collaboration', 'and', 'contact', 'center', 'solutions', 'announced', 'the', 'acquisition', 'of', 'marianaiq', 'miq', 'high', 'growth', 'silicon', 'valley', 'startup', 'as', 'part', 'of', 'the', 'strategic', 'investments', 'it', 'has', 'been', 'making', 'in', 'ai', 'and', 'machine', 'learning', 'miq', 'brings', 'deep', 'learning', 'capabilities', 'to', 'the', 'newly', 'announced', 'series', 'to', 'transform', 'both', 'employee', 'and', 'customer', 'experience', 'the', 'miq', 'team', 'including', 'founders', 'soumyadeb', 'mitra', 'and', 'venkat', 'nagaswamy', 'have', 'been', 'leaders', 'in', 'applying', 'ai', 'and', 'deep', 'learning', 'to', 'practical', 'business', 'problems', 'since', 'and', 'join', 'to', 'strengthen', 'ai', 'capabilities', 'for', 'enterprise', 'communications', 'has', 'continuously', 'evolved', 'itself', 'to', 'provide', 'best', 'in', 'class', 'enterprise', 'communications', 'to', 'our', 'customers', 'with', 'the', 'acquisition', 'of', 'marianaiq', 'we', 'are', 'fundamentally', 'transforming', 'how', 'customers', 'and', 'employees', 'interact', 'through', 'one', 'system', 'of', 'engagement', 'and', 'how', 'companies', 'optimize', 'valuable', 'moments', 'of', 'customer', 'engagement', 'with', 'one', 'set', 'of', 'data', 'in', 'one', 'system', 'of', 'intelligence', 'said', 'dejan', 'deklich', 'chief', 'product', 'officer', 'we', 'are', 'thrilled', 'to', 'add', 'top', 'notch', 'ai', 'talent', 'to', 'strengthen', 'market', 'leadership', 'in', 'the', 'billion', 'dollar', 'enterprise', 'engagement', 'management', 'market', 'customer', 'experience', 'is', 'the', 'cios', 'new', 'battlefield', 'according', 'to', 'gartner', 'cio', 'agenda', 'survey', 'nearly', 'half', 'of', 'cios', 'plan', 'to', 'deploy', 'artificial', 'intelligence', 'to', 'improve', 'customer', 'experience', 'the', 'ai', 'and', 'machine', 'learning', 'team', 'will', 'help', 'cios', 'win', 'the', 'customer', 'experience', 'battle', 'with', 'these', 'key', 'capabilities', 'context', 'rich', 'customer', 'engagements', 'the', 'ai', 'team', 'will', 'enhance', 'the', 'series', 'single', 'system', 'of', 'intelligence', 'platform', 'to', 'weave', 'in', 'contextual', 'personalization', 'for', 'omni', 'channel', 'services', 'by', 'infusing', 'miq', 'deep', 'learning', 'capabilities', 'into', 'series', 'contact', 'center', 'agents', 'can', 'have', 'detailed', 'information', 'on', 'previous', 'interactions', 'complete', 'customer', 'history', 'and', 'degree', 'context', 'before', 'they', 'even', 'start', 'conversation', 'intelligent', 'call', 'routing', 'ai', 'capabilities', 'will', 'bring', 'intelligent', 'call', 'routing', 'to', 'call', 'centers', 'as', 'critical', 'component', 'of', 'the', 'customer', 'experience', 'transformation', 'intelligent', 'routing', 'will', 'identify', 'the', 'caller', 'and', 'the', 'reason', 'for', 'the', 'call', 'to', 'assign', 'the', 'customer', 'to', 'the', 'right', 'agent', 'executive', 'or', 'subject', 'matter', 'expert', 'this', 'significantly', 'speeds', 'first', 'call', 'resolution', 'and', 'transforms', 'the', 'overall', 'customer', 'experience', 'speech', 'analytics', 'voice', 'of', 'the', 'customer', 'insights', 'enable', 'companies', 'to', 'optimize', 'customer', 'experiences', 'through', 'data', 'driven', 'decisions', 'with', 'powerful', 'speech', 'analytics', 'enabled', 'by', 'companies', 'can', 'now', 'analyze', 'customer', 'interactions', 'for', 'compliance', 'deeper', 'insights', 'and', 'agent', 'performance', 'purposes', 'speech', 'analytics', 'powered', 'by', 'natural', 'language', 'processing', 'technology', 'can', 'help', 'agents', 'inside', 'sales', 'and', 'customer', 'success', 'teams', 'effectively', 'identify', 'upsell', 'opportunities', 'or', 'escalate', 'at', 'risk', 'customers', 'to', 'the', 'highest', 'level', 'of', 'service', 'acquisitions', 'remain', 'key', 'part', 'of', 'our', 'strategy', 'to', 'continuously', 'innova ...
# Wall time: 9.83 s

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=1, threshold=1) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=1)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
# NLTK Stop words
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
#stop_words.extend(['from', 'subject', 're', 'edu','to','company','say','today','announce','also','edi','well','include','help','said','technology','disclose','would','avalara','indix','amazon','appfolio','dynasty','black knight','blackknight','knight','heavywater','cylance','blackberry','cognex','sualab','sailpoint','salesforce','redwood','city','sonasoft','optimaize','8x8','marianaiq','apple','siri','cisco','mindmeld','conversionpoint','inuvo','inc.','fronteo','edi','hewlett','packard','mapr','ibm','ibm1','ibm2','alchemyapi','alchemy','nvidia','mellanox','recall','studios','us','evolution','rocket','fuel','plus','x','s&p','kensho','sealed','intellibot','grapevine','seven','stars','sysorex','lightminer','veritone','box','zd','ventures','bluesence','acquisition','berkshire','base','take','know','want','deal','go','new','even','make','found','many','aquire','founder','nearly','ten','use','enable','global'])
stop_words.extend(stopwords1)
stop_words.extend(stopwords2)
stop_words.extend(['bluesence','iridescent','snapchat','veritone','ubera','avast','mediamath','sophos','also','company','solution','technology','say','acquisition','include','acquire','well','ax','shiseido','servicenow','israeli','japanese','make','baidu','avaya','aiware','oss','avaya'])
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", '8x8', 'accenture', 'accenture', 'accenture', 'accenture', 'accenture', 'accenture', 'accuray incorporated', 'acuityads holdings inc.', 'airgas inc', 'akamai technologies, inc', 'akamai technologies, inc', 'alliance healthcare services', 'amazon', 'amazon', 'ansys, inc.', 'aol', 'aon', 'appfolio, inc.', 'apple', 'apple', 'apple', 'aptiv plc', 'artificial life, inc.', 'autodesk, inc.', 'autodesk, inc.', 'avalara', 'avaya holdings corp', 'avra medical robotics', 'bain & company', 'baker hughes', 'barracuda networks inc.', 'benefitfocus inc', 'black knight', 'blackberry', 'boeing', 'boeing', 'bruker corporation', 'cadence design systems', 'cadence design systems', 'charles river laboratories', 'cisco systems inc', 'cision', 'citi', 'cloudera inc.', 'cognex corporation', 'compliance systems corporation', 'conversionpoint', 'criteo', 'cubic corporation', 'dassault systã\x83æ\x92ã\x82â¨mes', 'dell', 'diagnos inc.', 'ebay', 'ebay', 'envestnet and yodlee', 'epam systems, inc.', 'exacttarget', 'facebook', 'frankly inc.', 'fronteo usa, inc.', 'gaia inc', 'gbt technologies inc', 'ge healthcare', 'ge healthcare', 'ge healthcare', 'geckosystems international corporation', 'genpact', 'genpact', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'gtx corp', 'guidewire software', 'helomics (a predictive oncology subsidiary)', 'here (a nokia company)', 'hewlett packard enterprise', 'hewlett packard enterprise', 'houghton mifflin harcourt', 'hsbc', 'huami corporation', 'ibm', 'ibm', 'ibm', 'ibm', 'ibm', 'ibm', 'ibm', 'ibm', 'ibm', 'ibm', 'ibm watson health', 'icbs ltd.', 'identillect technologies corp', 'inferx corp.', 'infosys', 'intel', 'intel', 'intel', 'intel corporation', 'intellect seec (a polaris group company)', 'irobot corp.', 'jetblue', 'kaman corporation', 'laboratory corporation of america holdings', 'lg', 'liveperson inc', 'lockheed martin', 'mateon therapeutics, inc.', 'mckesson', 'medicomp, inc', 'medtronic', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microsoft', 'microstrategy', 'milacron holdings corp.', 'morningstar inc.', 'naver corporation', 'netapp', 'nextech ar solutions corp.', 'nice', 'ntt communications corporation', 'nvidia', 'nvidia', 'nvidia', 'nvidia', 'nvidia', 'nvidia', 'nvidia', 'nvidia', 'omnicom', 'on semiconductor', 'onpoint medical diagnostics', 'open source health inc.', 'oracle', 'orangehook, inc.', 'par technology', 'parsons', 'pitney b ...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
import spacy

# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatizing = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
data_lemmatized = remove_stopwords(data_lemmatizing)
print(data_lemmatized)
# Out:
# [['phone', 'meeting', 'collaboration', 'startup', 'part', 'strategic', 'investment', 'learn', 'bring', 'capability', 'newly', 'announce', 'series', 'transform', 'employee', 'miq', 'team_including', 'founder', 'soumyadeb', 'nagaswamy', 'leader', 'deep_learne', 'practical', 'continuously', 'evolve', 'provide', 'good', 'class', 'customer', 'fundamentally', 'transform', 'interact', 'engagement', 'optimize', 'valuable', 'moment', 'set', 'datum', 'intelligence', 'deklich', 'officer', 'thrill', 'add', 'ai', 'talent', 'strengthen', 'enterprise', 'engagement', 'cio', 'new', 'battlefield', 'accord', 'survey', 'nearly', 'cio', 'plan', 'deploy', 'experience', 'learning', 'team', 'help', 'cio', 'win', 'battle', 'context', 'engagement', 'enhance', 'system', 'intelligence', 'platform', 'weave', 'contextual', 'personalization', 'service', 'infuse', 'capabilitie', 'series', 'agent', 'detail', 'information', 'complete', 'customer', 'history', 'degree', 'context', 'even', 'start', 'conversation', 'route', 'bring', 'route', 'transformation', 'intelligent', 'route', 'customer', 'right', 'agent', 'expert', 'significantly', 'speed', 'first', 'call', 'resolution', 'transform', 'experience', 'voice', 'enable', 'optimize', 'decision', 'powerful', 'speech_analytic', 'enable', 'interaction', 'compliance', 'agent', 'performance', 'purpose', 'power', 'processing', 'help', 'agent', 'sale', 'team', 'effectively', 'identify', 'upsell', 'opportunity', 'escalate', 'risk', 'customer', 'high', 'level', 'service', 'remain', 'strategy', 'continuously', 'innovate', 'disrupt', 'space', 'enhance', 'capabilitie', 'player', 'offer', 'interoperable', 'chat', 'system', 'speak', 'slack', 'stride', 'enterprise', 'level', 'chat', 'application', 'right', 'investment', 'system', 'engagement', 'intelligence', 'experience', 'employee', 'customer'], ['global', 'support_client', 'program', 'firm', 'collaboration', 'digital', 'disruption', 'internet', 'things_iot', 'base', 'new_jersey', 'employ', 'informationist', 'engineering', 'picture', 'service', 'comment', 'data_revolution', 'power', 'enterprise', 'insight', 'aspect', 'business', 'customer', 'gain', 'accelerate', 'data', 'service', 'client', 'use', 'stop', 'notch', 'talent', 'prove', 'data'], ['system', 'base', 'second', 'recent', 'day', 'part', 'push', 'cloud_security', 'announce', 'provide', 'advisory', 'system', 'integration', 'service', 'supply_chain', 'procurement', 'financial_term', 'disclose', 'intrigo', 'found', 'bring', 'additional', 'resource', 'key', 'sap', 'sap', 'plan', 'supply_chain', 'collaboration', 'net', 'result', 'gain', 'expertise', 'help', 'enhance', 'customer', 'management', 'real_time', 'collaboration', 'supplier', 'come', 'turn', 'eye', 'supply_chain', 'function', 'customer', 'era', 'intelligent', 'supply_chain', 'ai', 'automation', 'analytic', 'allow', 'serve', 'growth_engine', 'connect', 'element', 'seamlessly', 'focus', 'service', 'intrigo', 'long_stande', 'relationship', 'help', 'create', 'develop', 'advanced', 'planning', 'optimization', 'work', 'build', 'deploy', 'supply_chain', 'collaboration'], ['service', 'outsource', 'acquiredus', 'base', 'creative', 'studio', 'term', 'transaction', 'disclose', 'capability', 'experience', 'strategy', 'digital', 'design', 'prototype', 'development', 'provide', 'interactive', 'expand', 'rapid_prototype', 'creative', 'capability', 'regional', 'foothold', 'talent', 'rich', 'market', 'found', 'base', 'plan', 'open', 'second', 'office', 'name', 'product', 'popular', 'disney', 'marvel', 'early', 'month', 'group', 'independent', 'set', 'prior', 'swedish', 'may', 'opened', 'brand', 'environment', 'experience', 'impact', 'social_media', 'experience'], ['swedish', 'specialize', 'strengthen', 'provide', 'interactive', 'result', 'client', 'access', 'intershop', 'software', 'term', 'transaction', 'disclose', 'see', 'many', 'european', 'retailer', 'manufacturer', 'ramp', 'investment', 'commerce', 'look', 'commerce', 'lead', 'expand', 'end', 'help_client', 'develop', 'digital ...

# %%
import gensim.corpora as corpora
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)
# Create Corpus
texts = data_lemmatized
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# View
print(corpus)
# Out:
# [[(0, 1), (1, 1), (2, 4), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1), (8, 2), (9, 1), (10, 2), (11, 1), (12, 2), (13, 3), (14, 1), (15, 1), (16, 1), (17, 1), (18, 2), (19, 1), (20, 2), (21, 1), (22, 5), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 2), (33, 2), (34, 4), (35, 2), (36, 2), (37, 1), (38, 1), (39, 1), (40, 3), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 2), (47, 1), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1), (53, 3), (54, 1), (55, 1), (56, 1), (57, 1), (58, 2), (59, 1), (60, 1), (61, 1), (62, 2), (63, 1), (64, 1), (65, 1), (66, 1), (67, 1), (68, 1), (69, 1), (70, 1), (71, 1), (72, 1), (73, 2), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 1), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 2), (90, 1), (91, 3), (92, 1), (93, 2), (94, 2), (95, 1), (96, 1), (97, 1), (98, 1), (99, 1), (100, 1), (101, 1), (102, 1), (103, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 3), (111, 1), (112, 2), (113, 1), (114, 1), (115, 3), (116, 1), (117, 1), (118, 1), (119, 1), (120, 1), (121, 1)], [(15, 1), (22, 1), (36, 1), (81, 1), (94, 2), (111, 1), (122, 1), (123, 1), (124, 1), (125, 1), (126, 1), (127, 1), (128, 2), (129, 1), (130, 1), (131, 1), (132, 1), (133, 1), (134, 1), (135, 1), (136, 1), (137, 1), (138, 1), (139, 1), (140, 1), (141, 1), (142, 1), (143, 1), (144, 1), (145, 1), (146, 1), (147, 1), (148, 1)], [(3, 1), (4, 1), (8, 1), (15, 3), (22, 2), (28, 1), (35, 1), (46, 2), (54, 1), (74, 1), (78, 1), (85, 1), (94, 2), (110, 2), (124, 1), (135, 1), (149, 1), (150, 1), (151, 1), (152, 1), (153, 1), (154, 1), (155, 1), (156, 1), (157, 1), (158, 1), (159, 1), (160, 1), (161, 1), (162, 1), (163, 1), (164, 1), (165, 1), (166, 1), (167, 1), (168, 1), (169, 1), (170, 1), (171, 1), (172, 1), (173, 2), (174, 1), (175, 1), (176, 1), (177, 1), (178, 1), (179, 1), (180, 1), (181, 1), (182, 1), (183, 1), (184, 1), (185, 1), (186, 1), (187, 2), (188, 1), (189, 1), (190, 1), (191, 1), (192, 5), (193, 1), (194, 1)], [(11, 2), (40, 3), (78, 1), (85, 1), (94, 1), (95, 1), (106, 1), (111, 1), (124, 2), (130, 1), (162, 1), (169, 1), (189, 1), (195, 1), (196, 1), (197, 2), (198, 1), (199, 1), (200, 1), (201, 1), (202, 1), (203, 1), (204, 1), (205, 1), (206, 1), (207, 1), (208, 1), (209, 1), (210, 1), (211, 1), (212, 1), (213, 1), (214, 1), (215, 1), (216, 1), (217, 1), (218, 1), (219, 1), (220, 1), (221, 1), (222, 1), (223, 1), (224, 1), (225, 1), (226, 1), (227, 1), (228, 1), (229, 1)], [(1, 1), (16, 1), (22, 1), (38, 1), (40, 3), (58, 1), (59, 1), (71, 1), (74, 2), (79, 1), (85, 3), (93, 2), (94, 2), (106, 1), (107, 3), (124, 1), (126, 1), (148, 1), (155, 1), (161, 1), (162, 1), (169, 1), (183, 1), (186, 1), (196, 3), (198, 1), (199, 1), (201, 1), (202, 1), (203, 2), (206, 1), (208, 4), (211, 1), (213, 1), (216, 1), (225, 1), (227, 1), (228, 1), (229, 1), (230, 1), (231, 1), (232, 1), (233, 4), (234, 1), (235, 1), (236, 1), (237, 1), (238, 2), (239, 1), (240, 3), (241, 1), (242, 1), (243, 1), (244, 1), (245, 1), (246, 1), (247, 1), (248, 1), (249, 1), (250, 1), (251, 1), (252, 1), (253, 1), (254, 1), (255, 1), (256, 1), (257, 1), (258, 1), (259, 1), (260, 1), (261, 1), (262, 1), (263, 1), (264, 1), (265, 1), (266, 1), (267, 1), (268, 1), (269, 2), (270, 1), (271, 1), (272, 1), (273, 1), (274, 1), (275, 1), (276, 1), (277, 1), (278, 1), (279, 1), (280, 1), (281, 4)], [(11, 1), (35, 1), (39, 1), (49, 1), (94, 1), (111, 1), (116, 1), (122, 1), (124, 1), (128, 1), (143, 1), (148, 1), (162, 1), (186, 1), (209, 1), (228, 1), (229, 1), (246, 3), (252, 2), (260, 1), (261, 2), (273, 1), (281, 1), (282, 1), (283, 1), (284, 1), (285, 1), (286, 1), (287, 1), (288, 1), (289, 1), (290, 1), (291, 3), (292, 1), (293, 1), (294, 1), (295, 1), (296, 1), (297, 1), (298, 1), (299, 1), (300, 1), (301, 1), (302, 1), (303, 1), (304, 1), (305, 1), (306, 1), (307, 1), (308, 1), (309, 1), (310, 1), (311, 1), (312, 1), (313, 1), (314, 1), (315, 1), (316, 1), (317 ...

# %%
# supporting function
from gensim.models import CoherenceModel

def compute_coherence_values(corpus, dictionary, k, a, b):
    
    lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=k, 
                                           random_state=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha=a,
                                           eta=b)
    
    coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
    
    return coherence_model_lda.get_coherence()

# %%
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=12,
                                           random_state=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha=0.31,
                                           eta=0.91)
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.49412829246056345

# %%
from pprint import pprint

# Print the Keyword in all topics
pprint(lda_model.print_topics(num_words=30))
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.001*"spoken" + 0.001*"business_card" + 0.001*"diabetes" + '
#   '0.000*"intelligentwire" + 0.000*"custom" + 0.000*"virtuoso" + 0.000*"speak" '
#   '+ 0.000*"naver" + 0.000*"france_base" + 0.000*"manpower" + 0.000*"asian" + '
#   '0.000*"ai_deep" + 0.000*"remember" + 0.000*"tech_firm" + 0.000*"advertiser" '
#   '+ 0.000*"app" + 0.000*"recognition_ocr" + 0.000*"smart_phone" + '
#   '0.000*"million_user" + 0.000*"domestic" + 0.000*"simulator" + '
#   '0.000*"photograph" + 0.000*"read" + 0.000*"card" + 0.000*"integrity" + '
#   '0.000*"mutual_customer" + 0.000*"synthesis" + 0.000*"innovus" + '
#   '0.000*"today_customer" + 0.000*"multitenant"'),
#  (1,
#   '0.001*"iphone" + 0.001*"phone" + 0.001*"face" + 0.000*"conscious" + '
#   '0.000*"deliberate" + 0.000*"hall_say" + 0.000*"chassis" + '
#   '0.000*"less_reliable" + 0.000*"inconvenient" + 0.000*"sunglasse" + '
#   '0.000*"touch_id" + 0.000*"upto" + 0.000*"ole" + 0.000*"cheap" + '
#   '0.000*"lense" + 0.000*"wear" + 0.000*"wet" + 0.000*"rumour" + '
#   '0.000*"widely_regarde" + 0.000*"unlocking" + 0.000*"fingerprint" + '
#   '0.000*"flip" + 0.000*"switch" + 0.000*"merit" + 0.000*"remove" + '
#   '0.000*"contact" + 0.000*"procedure" + 0.000*"widely" + 0.000*"calcalist" + '
#   '0.000*"front"'),
#  (2,
#   '0.001*"chipmaker" + 0.001*"combinator" + 0.001*"emarketer" + '
#   '0.001*"driverless" + 0.001*"altera" + 0.001*"intela" + 0.001*"lab" + '
#   '0.000*"experimental" + 0.000*"robot" + 0.000*"raibert" + 0.000*"impose" + '
#   '0.000*"mainland" + 0.000*"ravenh" + 0.000*"chinaenrolle" + '
#   '0.000*"search_ad" + 0.000*"death" + 0.000*"regulator" + 0.000*"anai" + '
#   '0.000*"hire" + 0.000*"foothold" + 0.000*"round" + 0.000*"carmaker" + '
#   '0.000*"conversational" + 0.000*"warning" + 0.000*"mobileyea" + 0.000*"boom" '
#   '+ 0.000*"pil" + 0.000*"shrink" + 0.000*"slew" + 0.000*"landmark"'),
#  (3,
#   '0.005*"spend" + 0.002*"coupa" + 0.002*"use" + 0.002*"search" + '
#   '0.002*"develop" + 0.002*"time" + 0.002*"snap" + 0.001*"head" + '
#   '0.001*"feature" + 0.001*"product" + 0.001*"employee" + 0.001*"lense" + '
#   '0.001*"blackbird" + 0.001*"know" + 0.001*"similar" + 0.001*"worldwide" + '
#   '0.001*"item" + 0.001*"even" + 0.001*"executive" + 0.001*"example" + '
#   '0.001*"first" + 0.001*"team" + 0.001*"filter" + 0.001*"story" + 0.001*"app" '
#   '+ 0.001*"etsya" + 0.001*"little" + 0.001*"year" + 0.001*"popular" + '
#   '0.001*"process"'),
#  (4,
#   '0.002*"app" + 0.001*"come" + 0.001*"available" + 0.001*"android" + '
#   '0.001*"join" + 0.001*"announcement" + 0.001*"youtube" + 0.001*"group" + '
#   '0.001*"call" + 0.001*"smartphone" + 0.001*"softbank" + 0.001*"son" + '
#   '0.001*"manager" + 0.001*"debt" + 0.001*"pound" + 0.001*"plan" + '
#   '0.001*"share" + 0.001*"year" + 0.001*"may" + 0.001*"announce" + '
#   '0.001*"focus" + 0.001*"take" + 0.001*"seem" + 0.001*"cash" + 0.001*"small" '
#   '+ 0.001*"learn" + 0.001*"able" + 0.001*"ability" + 0.001*"design" + '
#   '0.001*"shut"'),
#  (5,
#   '0.002*"sport" + 0.002*"cdi" + 0.001*"tempo" + 0.001*"sponsorship" + '
#   '0.001*"assistant" + 0.001*"predictive" + 0.001*"map" + 0.001*"act" + '
#   '0.001*"bring" + 0.001*"talent" + 0.001*"medio" + 0.001*"colt" + '
#   '0.001*"rights_holder" + 0.001*"nielsensport" + 0.001*"global_sport" + '
#   '0.001*"cdn_per" + 0.001*"incubator" + 0.001*"season" + '
#   '0.001*"expands_market" + 0.001*"cooper" + 0.001*"flagship" + '
#   '0.001*"opera_solution" + 0.001*"screen" + 0.001*"already" + 0.001*"host" + '
#   '0.001*"highly" + 0.001*"professional" + 0.001*"capable" + 0.001*"advisor" + '
#   '0.001*"competition"'),
#  (6,
#   '0.002*"self_driving" + 0.002*"car" + 0.001*"ottoa" + 0.001*"self_drive" + '
#   '0.001*"doesna_want" + 0.001*"kit" + 0.001*"ride" + 0.001*"mapping" + '
#   '0.001*"instead" + 0.001*"sailpoint" + 0.001*"space" + 0.001*"manufacturer" '
#   '+ 0.000*"morphormic" + 0.000*"road" + 0.000*"push" + 0.000*"ita" + '
#   '0.000*"tesla" + 0.000*"bloomberg" + 0.000*"could_help" + 0.000*"dismantle" '
#   '+ 0.000*"rona" + 0.000*"levandowski" + 0.000*"mappinga" + 0.000*"owna" + '
#   '0.000*"therea" + 0.000*"rid" + 0.000*"fits_perfectly" + '
#   '0.000*"lidar_sensor" + 0.000*"drastically" + 0.000*"truck"'),
#  (7,
#   '0.004*"adept" + 0.001*"act" + 0.001*"robotic" + 0.001*"controller" + '
#   '0.001*"automation" + 0.000*"food" + 0.000*"stock" + 0.000*"robot" + '
#   '0.000*"delighted" + 0.000*"offer_new" + 0.000*"robot_mechanism" + '
#   '0.000*"logistical" + 0.000*"foreign" + 0.000*"machine_vision" + '
#   '0.000*"adep" + 0.000*"shorten" + 0.000*"broad_range" + 0.000*"beverage" + '
#   '0.000*"dept" + 0.000*"omron" + 0.000*"whereby" + 0.000*"robot_solution" + '
#   '0.000*"expiration" + 0.000*"cain" + 0.000*"linear" + 0.000*"precision" + '
#   '0.000*"configurable" + 0.000*"enable_customer" + 0.000*"manufacturer" + '
#   '0.000*"labor"'),
#  (8,
#   '0.006*"customer" + 0.005*"provide" + 0.005*"base" + 0.004*"service" + '
#   '0.004*"product" + 0.004*"use" + 0.004*"software" + 0.004*"business" + '
#   '0.004*"platform" + 0.004*"system" + 0.004*"market" + 0.004*"capability" + '
#   '0.004*"datum" + 0.003*"deliver" + 0.003*"work" + 0.003*"focus" + '
#   '0.003*"help" + 0.003*"offer" + 0.003*"continue" + 0.003*"team" + '
#   '0.003*"partner" + 0.003*"enable" + 0.003*"security" + 0.003*"develop" + '
#   '0.003*"create" + 0.003*"announce" + 0.003*"share" + 0.003*"plan" + '
#   '0.003*"support" + 0.003*"cloud"'),
#  (9,
#   '0.001*"lab" + 0.001*"arimo" + 0.001*"barricade" + 0.001*"reply" + '
#   '0.001*"earnings_result" + 0.001*"turia" + 0.001*"promote" + 0.001*"ai" + '
#   '0.000*"strengthen" + 0.000*"visual" + 0.000*"data_science" + 0.000*"main" + '
#   '0.000*"initiate" + 0.000*"research" + 0.000*"effort" + 0.000*"home" + '
#   '0.000*"text" + 0.000*"develop" + 0.000*"researcher" + 0.000*"identillect" + '
#   '0.000*"spher" + 0.000*"element" + 0.000*"voice_base" + 0.000*"debut" + '
#   '0.000*"serious" + 0.000*"catch" + 0.000*"samsung" + 0.000*"south_korean" + '
#   '0.000*"frequently" + 0.000*"viv"'),
#  (10,
#   '0.001*"irobot" + 0.001*"bangalore" + 0.001*"abuse" + 0.001*"tegal" + '
#   '0.001*"abco" + 0.001*"mission" + 0.001*"amount" + 0.001*"fastest_growing" + '
#   '0.000*"site" + 0.000*"angle" + 0.000*"mint" + 0.000*"weld" + '
#   '0.000*"startup_base" + 0.000*"fighter" + 0.000*"getfacebookas" + '
#   '0.000*"indian_startup" + 0.000*"ripple" + 0.000*"cofounde" + '
#   '0.000*"aolventure" + 0.000*"criminal" + 0.000*"awhile" + 0.000*"miscreant" '
#   '+ 0.000*"jamal" + 0.000*"basedimpermium" + 0.000*"highland" + 0.000*"spam" '
#   '+ 0.000*"celebrate" + 0.000*"rid" + 0.000*"peg" + 0.000*"leave"'),
#  (11,
#   '0.005*"customer" + 0.005*"platform" + 0.005*"use" + 0.004*"service" + '
#   '0.004*"provide" + 0.004*"business" + 0.004*"base" + 0.004*"datum" + '
#   '0.004*"team" + 0.004*"analytic" + 0.004*"work" + 0.003*"develop" + '
#   '0.003*"experience" + 0.003*"product" + 0.003*"capability" + 0.003*"market" '
#   '+ 0.003*"help" + 0.003*"application" + 0.003*"lead" + 0.003*"build" + '
#   '0.003*"system" + 0.003*"offer" + 0.002*"support" + 0.002*"add" + '
#   '0.002*"client" + 0.002*"bring" + 0.002*"ai" + 0.002*"information" + '
#   '0.002*"user" + 0.002*"create"')]

# %%
Topic_0 = []
Topic_1 = []
Topic_2 = []
Topic_3 = []
Topic_4 = []
Topic_5 = []
Topic_6 = []
Topic_7 = []
Topic_8 = []
Topic_9 = []
Topic_10 = []
Topic_11 = []
#Topic_12 = []
#Topic_13 = []
Doc_No = []
data_lemmatized_word = []
for i, row in enumerate(lda_model[corpus]):
    #row = sorted(row, key=lambda x:x[1], reverse=True)
    Topic_0.append(0);
    Topic_1.append(0);
    Topic_2.append(0);
    Topic_3.append(0);
    Topic_4.append(0);
    Topic_5.append(0);
    Topic_6.append(0);
    Topic_7.append(0);
    Topic_8.append(0);
    Topic_9.append(0);
    Topic_10.append(0);
    Topic_11.append(0);
    #Topic_12.append(0);
    #Topic_13.append(0);
    Doc_No.append(i);
    data_lemmatized_word.append(data_lemmatized[i])
    for k in range(len(row)):
        if(row[k][0]==0):
            Topic_0[i]=row[k][1];
        if(row[k][0]==1):
            Topic_1[i]=row[k][1];
        if(row[k][0]==2):
            Topic_2[i]=row[k][1];
        if(row[k][0]==3):
            Topic_3[i]=row[k][1];
        if(row[k][0]==4):
            Topic_4[i]=row[k][1];
        if(row[k][0]==5):
            Topic_5[i]=row[k][1];
        if(row[k][0]==6):
            Topic_6[i]=row[k][1];
        if(row[k][0]==7):
            Topic_7[i]=row[k][1];
        if(row[k][0]==8):
            Topic_8[i]=row[k][1];
        if(row[k][0]==9):
            Topic_9[i]=row[k][1];
        if(row[k][0]==10):
            Topic_10[i]=row[k][1];
        if(row[k][0]==11):
            Topic_11[i]=row[k][1];
        #if(row[k][0]==12):
          #  Topic_12[i]=row[k][1];
        #if(row[k][0]==13):
          #  Topic_13[i]=row[k][1];
df = pd.DataFrame(list(zip(Doc_No, Topic_0, Topic_1, Topic_2, Topic_3, Topic_4, Topic_5, Topic_6, Topic_7, Topic_8, Topic_9, Topic_10, Topic_11, data_lemmatized_word)), 
               columns = ['Doc_No', 'Topic#0', 'Topic#1', 'Topic#2', 'Topic#3', 'Topic#4', 'Topic#5', 'Topic#6', 'Topic#7', 'Topic#8', 'Topic#9','Topic#10','Topic#11','Text'])
df.to_csv('Topic_Score_for_each_Document_Using_Trigrams_2.csv')
